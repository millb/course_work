# %% [markdown]
# <h1>Отчет №1.</h1>
# <br>
# <p>1. Изучение данных, поиск аномалий в данных и их последующая коррекция.<br>
#     2. Построение аналитической отчестности по данным.
# </p>
# <h4>Дата: 19.01.2021</h4>

# %% [markdown]
# <h2>Загрузка данных</h2>

# %%
import pandas as pd

# %%
order_data1 = pd.read_csv('../data/!07&08_17_VSE.csv', encoding="cp1251", engine='python', sep=';')
order_data2 = pd.read_csv('../data/!09&10_17_VSE.csv', encoding="cp1251", engine='python', sep=';')
order_data1.head()
# Out:
#               Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0  01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1  01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2  01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3  01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4  01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
#
#   СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  Регион  \
# 0              1 634          1 634      Магазины  Безналичная  Москва
# 1              1 634          1 634      Магазины  Безналичная  Москва
# 2              1 634          1 634      Магазины  Безналичная  Москва
# 3              1 634          1 634      Магазины  Безналичная  Москва
# 4              1 634          1 634      Магазины  Безналичная  Москва
#
#               Группа2                   Группа3   Группа4     Тип  \
# 0  ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ     носки  ОДЕЖДА
# 1  ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ     носки  ОДЕЖДА
# 2  ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ     носки  ОДЕЖДА
# 3  ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ     носки  ОДЕЖДА
# 4  ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ  колготки  ОДЕЖДА
#
#                          Номенклатура ТипТовара Отменено ПричинаОтмены  \
# 0     МАТЭКО, НОСКИ (зелен), р. 12-14       МГТ      Нет           NaN
# 1     МАТЭКО, НОСКИ (т.син), р. 12-14       МГТ      Нет           NaN
# 2        ЗАЙКА МОЯ, НОСКИ дет., р. 14       МГТ      Нет           NaN
# 3        ЗАЙКА МОЯ, НОСКИ дет., р. 14       МГТ      Нет           NaN
# 4  ЗАЙКА МОЯ, КОЛГОТКИ дет., р. 92-98       МГТ      Нет           NaN
#
#    Количество Цена СуммаСтроки ЦенаЗакупки  МесяцДатыЗаказа ГодДатыЗаказа  \
# 0           1   50          50        23,1                7         2 017
# 1           1   50          50        23,1                7         2 017
# 2           1   49          49       40,96                7         2 017
# 3           1   40          40       34,21                7         2 017
# 4           1  169         169      105,21                7         2 017
#
#      ПВЗ_код     Статус     Гео  Маржа СуммаУслуг СуммаДоставки  НомерСтроки  \
# 0  901000646  Доставлен  Москва   26,9         49            49            3
# 1  901000646  Доставлен  Москва   26,9         49            49            4
# 2  901000646  Доставлен  Москва   8,04         49            49            7
# 3  901000646  Доставлен  Москва   5,79         49            49            1
# 4  901000646  Доставлен  Москва  63,79         49            49            9
#
#    КоличествоПроданоКлиенту ДатаЗаказаНаСайте              Телефон_new  \
# 0                         1   30.06.2017 0:00  55574948-52495050484877
# 1                         1   30.06.2017 0:00  55574948-52495050484877
# 2                         1   30.06.2017 0:00  55574948-52495050484877
# 3                         1   30.06.2017 0:00  55574948-52495050484877
# 4                         1   30.06.2017 0:00  55574948-52495050484877
#
#   ЭлектроннаяПочта_new   Клиент          ID_SKU ГородМагазина МагазинЗаказа
# 0  116117_tu17@mail.ru  Татьяна  IDL00051334048             0           NaN
# 1  116117_tu17@mail.ru  Татьяна  IDL00051367351             0           NaN
# 2  116117_tu17@mail.ru  Татьяна  IDL00007611755             0           NaN
# 3  116117_tu17@mail.ru  Татьяна  IDL00014478250             0           NaN
# 4  116117_tu17@mail.ru  Татьяна  IDL00001209351             0           NaN

# %% [markdown]
# Смотрим на первоначальный размер данных:

# %%
print(order_data1.shape)
print(order_data2.shape)
# Out:
# (797192, 38)
# (876075, 38)

# %%
order_data = order_data1
order_data = order_data.append(order_data2, ignore_index=True)
order_data
# Out:
#                      Дата     ДатаДоставки НомерЗаказаНаСайте     НовыйСтатус  \
# 0         01.07.2017 0:00  06.07.2017 0:00         5031788_TR       Доставлен
# 1         01.07.2017 0:00  06.07.2017 0:00         5031788_TR       Доставлен
# 2         01.07.2017 0:00  06.07.2017 0:00         5031788_TR       Доставлен
# 3         01.07.2017 0:00  06.07.2017 0:00         5031788_TR       Доставлен
# 4         01.07.2017 0:00  06.07.2017 0:00         5031788_TR       Доставлен
# ...                   ...              ...                ...             ...
# 1673262  31.10.2017 23:59  02.11.2017 0:00         6005071_ES      К отгрузке
# 1673263  31.10.2017 23:59  02.11.2017 0:00         6005071_ES      К отгрузке
# 1673264  31.10.2017 23:59  03.11.2017 0:00         6005077_ES  Возврат из ПВЗ
# 1673265  31.10.2017 23:59  03.11.2017 0:00         6005089_ES  Возврат из ПВЗ
# 1673266  31.10.2017 23:59  03.11.2017 0:00         6005101_ES       Доставлен
#
#         СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  Регион  \
# 0                    1 634          1 634      Магазины  Безналичная  Москва
# 1                    1 634          1 634      Магазины  Безналичная  Москва
# 2                    1 634          1 634      Магазины  Безналичная  Москва
# 3                    1 634          1 634      Магазины  Безналичная  Москва
# 4                    1 634          1 634      Магазины  Безналичная  Москва
# ...                    ...            ...           ...          ...     ...
# 1673262              3 222          3 222    Курьерская     Наличная  Москва
# 1673263              3 222          3 222    Курьерская     Наличная  Москва
# 1673264              2 564          2 564      Магазины  Безналичная  Москва
# 1673265              2 564          2 564      Магазины  Безналичная  Москва
# 1673266                848            848      Магазины  Безналичная  Москва
#
#                      Группа2                   Группа3  \
# 0         ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ
# 1         ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ
# 2         ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ
# 3         ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ
# 4         ТЕКСТИЛЬ, ТРИКОТАЖ  ДЕТСКИЕ КОЛГОТКИ И НОСКИ
# ...                      ...                       ...
# 1673262    КОСМЕТИКА/ГИГИЕНА    СРЕДСТВА БЫТОВОЙ ХИМИИ
# 1673263    КОСМЕТИКА/ГИГИЕНА    СРЕДСТВА БЫТОВОЙ ХИМИИ
# 1673264              ИГРУШКИ     ИГРУШКИ ДЛЯ МАЛЬЧИКОВ
# 1673265              ИГРУШКИ     ИГРУШКИ ДЛЯ МАЛЬЧИКОВ
# 1673266  ТОВАРЫ ДЛЯ ЖИВОТНЫХ          ТОВАРЫ ДЛЯ СОБАК
#
#                         Группа4      Тип  \
# 0                         носки   ОДЕЖДА
# 1                         носки   ОДЕЖДА
# 2                         носки   ОДЕЖДА
# 3                         носки   ОДЕЖДА
# 4                      колготки   ОДЕЖДА
# ...                         ...      ...
# 1673262  кондиционеры для белья     ППКП
# 1673263  кондиционеры для белья     ППКП
# 1673264         треки, парковки  ИГРУШКИ
# 1673265         треки, парковки  ИГРУШКИ
# 1673266         пеленки и лотки     ИНОЕ
#
#                                               Номенклатура ТипТовара Отменено  \
# 0                          МАТЭКО, НОСКИ (зелен), р. 12-14       МГТ      Нет
# 1                          МАТЭКО, НОСКИ (т.син), р. 12-14       МГТ      Нет
# 2                             ЗАЙКА МОЯ, НОСКИ дет., р. 14       МГТ      Нет
# 3                             ЗАЙКА МОЯ, НОСКИ дет., р. 14       МГТ      Нет
# 4                       ЗАЙКА МОЯ, КОЛГОТКИ дет., р. 92-98       МГТ      Нет
# ...                                                    ...       ...      ...
# 1673262      BURTI, ОПОЛАСКИВАТЕЛЬ с запахом розы, (1,5 л)       МГТ      Нет
# 1673263   BURTI, ОПОЛАСКИВАТЕЛЬ с запахом лаванды, (1,5 л)       МГТ      Нет
# 1673264      HOT WHEELS, НАБОР стартовый Конструктор трасс       МГТ      Нет
# 1673265      HOT WHEELS, НАБОР стартовый Конструктор трасс       МГТ      Нет
# 1673266  Пеленки EVERYDAY для животных гелевые, 60*45 с...       МГТ      Нет
#
#         ПричинаОтмены  Количество   Цена СуммаСтроки ЦенаЗакупки  \
# 0                 NaN           1     50          50        23,1
# 1                 NaN           1     50          50        23,1
# 2                 NaN           1     49          49       40,96
# 3                 NaN           1     40          40       34,21
# 4                 NaN           1    169         169      105,21
# ...               ...         ...    ...         ...         ...
# 1673262           NaN           2    297         594         253
# 1673263           NaN           2    281         562         253
# 1673264           NaN           1  2 564       2 564       2 233
# 1673265           NaN           1  2 564       2 564       2 233
# 1673266           NaN           2    424         848       404,6
#
#          МесяцДатыЗаказа ГодДатыЗаказа    ПВЗ_код     Статус     Гео  Маржа  \
# 0                      7         2 017  901000646  Доставлен  Москва   26,9
# 1                      7         2 017  901000646  Доставлен  Москва   26,9
# 2                      7         2 017  901000646  Доставлен  Москва   8,04
# 3                      7         2 017  901000646  Доставлен  Москва   5,79
# 4                      7         2 017  901000646  Доставлен  Москва  63,79
# ...                  ...           ...        ...        ...     ...    ...
# 1673262               10         2 017        NaN  Доставлен  Москва     88
# 1673263               10         2 017        NaN  Доставлен  Москва     56
# 1673264               10         2 017      23111    Возврат  Москва    331
# 1673265               10         2 017      23111    Возврат  Москва    331
# 1673266               10         2 017  GL0285876  Доставлен  Москва   38,8
#
#         СуммаУслуг СуммаДоставки  НомерСтроки  КоличествоПроданоКлиенту  \
# 0               49            49            3                         1
# 1               49            49            4                         1
# 2               49            49            7                         1
# 3               49            49            1                         1
# 4               49            49            9                         1
# ...            ...           ...          ...                       ...
# 1673262        150           150            3                         2
# 1673263        150           150            2                         2
# 1673264          0             0            1                         0
# 1673265          0             0            1                         0
# 1673266          0             0            1                         2
#
#         ДатаЗаказаНаСайте              Телефон_new   ЭлектроннаяПочта_new  \
# 0         30.06.2017 0:00  55574948-52495050484877    116117_tu17@mail.ru
# 1         30.06.2017 0:00  55574948-52495050484877    116117_tu17@mail.ru
# 2         30.06.2017 0:00  55574948-52495050484877    116117_tu17@mail.ru
# 3         30.06.2017 0:00  55574948-52495050484877    116117_tu17@mail.ru
# 4         30.06.2017 0:00  55574948-52495050484877    116117_tu17@mail.ru
# ...                   ...                      ...                    ...
# 1673262   31.10.2017 0:00  55574953-52575355515475   109117_mu19@inbox.ru
# 1673263   31.10.2017 0:00  55574953-52575355515475   109117_mu19@inbox.ru
# 1673264   31.10.2017 0:00  55574857-54545754565577     97117_au19@mail.ru
# 1673265   31.10.2017 0:00  55574857-54545754565577     97117_au19@mail.ru
# 1673266   31.10.2017 0:00  55575054-56564948515679  112109_pm21@gmail.com
#
#           Клиент          ID_SKU ГородМагазина МагазинЗаказа
# 0        Татьяна  IDL00051334048             0           NaN
# 1        Татьяна  IDL00051367351             0           NaN
# 2        Татьяна  IDL00007611755             0           NaN
# 3        Татьяна  IDL00014478250             0           NaN
# 4        Татьяна  IDL00001209351             0           NaN
# ...          ...             ...           ...           ...
# 1673262    Мария  IDL00039538654             0           NaN
# 1673263    Мария  IDL00039538755             0           NaN
# 1673264  Дмитрий  IDL00043615553             0           NaN
# 1673265  Дмитрий  IDL00043615553             0           NaN
# 1673266   Иванов  IDL00032748755             0           NaN
#
# [1673267 rows x 38 columns]

# %% [markdown]
# Как можно было заметить отображаются не все колонки. Исправим это:

# %%
pd.options.display.max_columns = 40

# %% [markdown]
# ## Исследование и коррекция данных ##

# %% [markdown]
# Посмотрим на количество пропущенных значений по столбцам

# %%
order_data.isna().sum()
# Out:
# Дата                              0
# ДатаДоставки                   1230
# НомерЗаказаНаСайте                0
# НовыйСтатус                       0
# СуммаЗаказаНаСайте                0
# СуммаДокумента                    0
# МетодДоставки                   114
# ФормаОплаты                     116
# Регион                         9845
# Группа2                      325123
# Группа3                      325123
# Группа4                      381269
# Тип                               0
# Номенклатура                      0
# ТипТовара                    325123
# Отменено                          0
# ПричинаОтмены               1509914
# Количество                        0
# Цена                              0
# СуммаСтроки                       0
# ЦенаЗакупки                  329966
# МесяцДатыЗаказа                   0
# ГодДатыЗаказа                     0
# ПВЗ_код                      442742
# Статус                            0
# Гео                               0
# Маржа                        329966
# СуммаУслуг                        0
# СуммаДоставки                     0
# НомерСтроки                       0
# КоличествоПроданоКлиенту          0
# ДатаЗаказаНаСайте                 0
# Телефон_new                       0
# ЭлектроннаяПочта_new          26533
# Клиент                          431
# ID_SKU                            0
# ГородМагазина                     0
# МагазинЗаказа               1663538
# dtype: int64

# %% [markdown]
# Рассмотрим числовые показатели
# * СуммаЗаказаНаСайте
# * СуммаДокумента
# * Количество
# * Цена
# * СуммаСтроки
# * ЦенаЗакупки
# * Маржа
# * СуммаУслуг
# * СуммаДоставки
# * КоличествоПроданоКлиенту

# %%
order_data.dtypes
# Out:
# Дата                        object
# ДатаДоставки                object
# НомерЗаказаНаСайте          object
# НовыйСтатус                 object
# СуммаЗаказаНаСайте          object
# СуммаДокумента              object
# МетодДоставки               object
# ФормаОплаты                 object
# Регион                      object
# Группа2                     object
# Группа3                     object
# Группа4                     object
# Тип                         object
# Номенклатура                object
# ТипТовара                   object
# Отменено                    object
# ПричинаОтмены               object
# Количество                   int64
# Цена                        object
# СуммаСтроки                 object
# ЦенаЗакупки                 object
# МесяцДатыЗаказа              int64
# ГодДатыЗаказа               object
# ПВЗ_код                     object
# Статус                      object
# Гео                         object
# Маржа                       object
# СуммаУслуг                  object
# СуммаДоставки               object
# НомерСтроки                  int64
# КоличествоПроданоКлиенту     int64
# ДатаЗаказаНаСайте           object
# Телефон_new                 object
# ЭлектроннаяПочта_new        object
# Клиент                      object
# ID_SKU                      object
# ГородМагазина               object
# МагазинЗаказа               object
# dtype: object

# %% [markdown]
# Следовательно, необходимо изменить типы колонок:
#
# 'Дата', 'ДатаЗаказаНаСайте' -> `datetime`
#
# 'СуммаЗаказаНаСайте', 'СуммаДокумента', 'Маржа' -> `float`
#
# 'Цена', 'СуммаСтроки', 'ЦенаЗакупки' -> `float`

# %% [markdown]
# Посмотрим на 'СуммаЗаказаНаСайте' и 'СуммаДокумента'. По логике они должны быть равны, так как обозначают одно и тоже.

# %%
order_data[order_data['СуммаЗаказаНаСайте'] != order_data['СуммаДокумента']].shape[0]
# Out:
# 506503

# %% [markdown]
# Как мы можем заметить строчек где 'СуммаЗаказаНаСайте' не равна 'СуммеДокумента' много. Чтобы не разбираться с каждым случаем отдельно мы удалим эти колонки и пересчитаем их если они понадобятся. Соотвественно в дальнейшем мы будем считать, что 'Цена', 'ЦенаЗакупки' и 'Количество' и 'КоличествоПроданоКлиенту' приходят к нам без ошибок (строчки где эти данные пропущены мы удалим) и все основные показатели будем пересчитывать через них.

# %% [markdown]
# Разберемся с доставкой. Как мы видим у доставки 'Тип' = ИНОЕ (Заметим, что только у доставки тип ИНОЕ) и пропущена 'ЦенаЗакупки'. Так как непонятно какая маржа у доставки (цена или 0), то во избежание двоякой трактовки мы исключим доставку из общего анализа (при расчете среднего чека и т.д.) и позже проанализируем данный тип отдельно.

# %%
order_data[order_data['Номенклатура'] == 'Доставка'].head()
# Out:
#                 Дата     ДатаДоставки НомерЗаказаНаСайте     НовыйСтатус  \
# 7    01.07.2017 0:00  06.07.2017 0:00         5031788_TR       Доставлен
# 14   01.07.2017 0:00  14.07.2017 0:00         5031790_TR       Доставлен
# 27   01.07.2017 0:00  08.07.2017 0:00         5031791_TR       Доставлен
# 28   01.07.2017 0:01  04.07.2017 0:00         5031806_TR  Возврат из ПВЗ
# 30  01.07.2017 10:01  02.07.2017 0:00         5031883_ES      К отгрузке
#
#    СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  Регион  \
# 7               1 634          1 634      Магазины  Безналичная  Москва
# 14              1 915          1 915      Магазины  Безналичная    Сочи
# 27              1 218          1 218      Магазины  Безналичная  Самара
# 28              3 089          3 089      Магазины  Безналичная  Москва
# 30              2 198          2 198    Курьерская     Наличная  Москва
#
#    Группа2 Группа3 Группа4   Тип Номенклатура ТипТовара Отменено  \
# 7      NaN     NaN     NaN  ИНОЕ     Доставка       NaN      Нет
# 14     NaN     NaN     NaN  ИНОЕ     Доставка       NaN      Нет
# 27     NaN     NaN     NaN  ИНОЕ     Доставка       NaN      Нет
# 28     NaN     NaN     NaN  ИНОЕ     Доставка       NaN      Нет
# 30     NaN     NaN     NaN  ИНОЕ     Доставка       NaN      Нет
#
#    ПричинаОтмены  Количество Цена СуммаСтроки ЦенаЗакупки  МесяцДатыЗаказа  \
# 7            NaN           1   49          49         NaN                7
# 14           NaN           1   99          99         NaN                7
# 27           NaN           1   99          99         NaN                7
# 28           NaN           1   49          49         NaN                7
# 30           NaN           1  150         150         NaN                7
#
#    ГодДатыЗаказа    ПВЗ_код     Статус      Гео Маржа СуммаУслуг  \
# 7          2 017  901000646  Доставлен   Москва   NaN         49
# 14         2 017      23111  Доставлен  Регионы   NaN         99
# 27         2 017      23111  Доставлен  Регионы   NaN         99
# 28         2 017      23111    Возврат   Москва   NaN         49
# 30         2 017        NaN  Доставлен   Москва   NaN        150
#
#    СуммаДоставки  НомерСтроки  КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 7             49            1                         1   30.06.2017 0:00
# 14            99            1                         1   30.06.2017 0:00
# 27            99            1                         1   30.06.2017 0:00
# 28            49            1                         1   30.06.2017 0:00
# 30           150            1                         1   30.06.2017 0:00
#
#                 Телефон_new   ЭлектроннаяПочта_new     Клиент         ID_SKU  \
# 7   55574948-52495050484877    116117_tu17@mail.ru    Татьяна  ID10022107250
# 14  55575656-49565651494970  107117_ku23@yandex.ru  Екатерина  ID10022107250
# 27  55575155-54535648525672   97117_au28@yandex.ru      Гость  ID10022107250
# 28  55575451-55554850515276     97117_au19@mail.ru    Наумова  ID10022107250
# 30  55575456-55545450525776     112117_pu11@nln.ru      Павел  ID10022107250
#
#    ГородМагазина МагазинЗаказа
# 7              0           NaN
# 14             0           NaN
# 27             0           NaN
# 28             0           NaN
# 30             0           NaN

# %% [markdown]
# Теперь надо определиться как работать с фродом. Фродом будем считать чеки, где присутствует отрицательная маржа в размере -300. Соответственно такие чеки мы удалим.

# %% [markdown]
# Осталось подумать, как удалить дубликаты и какие они вообще могут быть.
# Первой идеей было удалять чеки с одинаковыми товарами и статусом заказа. Однако данная идея не получила поддержки
# так как ничего не мешает заказать клиенту один и тот же набор несколько раз. Поэтому было решено сделать следующее:
# Удалить повторяющие строчки, только если они совпадают полностью, включая номер заказа.

# %% [markdown]
# ### Функция подготовки данных ###
# После вышеизложенного исследования данных можно сформулировать что должна делать первая функция по отчистке и подготовке данных:
#
# * Удалить все строчки где 'Номенклатура' = 'Доставка'
# * Удалить все строчки где пропущены значения в колонках 'ЦенаЗакупки', 'Цена' или 'Количество'
# * Преобразовать колонки в правильный тип
# * Пересчитать правильно маржу и сумму строки
# * Удалить дубликаты если они есть
# * Удалить фрод, то есть чеки в которых присутсвуют товары с большой отрицательной маржой
# * Удалить колонки 'СуммаЗаказаНаСайте', 'СуммаДокумента' чтобы избежать неправильной трактовки в дальнейшем

# %%
def object_columns_to_float_columns(data, column_names):
    for column_name in column_names:
        data[column_name] = data[column_name].apply(lambda x : x.replace(',', '.'))
        data[column_name] = data[column_name].apply(lambda x : x.replace(' ', ''))
        data[column_name] = pd.to_numeric(data[column_name])
    return data

# %%
def prepare_data(data):
    ### TO DO: check month and years
    ### TO DO: reset_indices
    
    current_number_of_raws = data.shape[0]
    data = data[data['Номенклатура'] != 'Доставка']
    print('Количество удаленных строк, которые описывают доставку: ', current_number_of_raws - data.shape[0])
    current_number_of_raws = data.shape[0]
    data = data.dropna(subset=['Количество', 'Цена', 'ЦенаЗакупки'])
    print('Количество удаленных строк, где пропущены ключевые значения: ', current_number_of_raws - data.shape[0])
    
    data = object_columns_to_float_columns(data, ['СуммаДокумента', 'СуммаЗаказаНаСайте', 'СуммаСтроки', 'ЦенаЗакупки', 'Цена'])
    
    ### TO DO: object_columns_to_data
    
    data['СуммаСтроки'] = data['Цена'] * data['Количество']
    data['Маржа'] = (data['Цена'] - data['ЦенаЗакупки']) * data['Количество']
    data
    
    current_number_of_raws = data.shape[0]
    data = data.drop_duplicates(subset=data.columns, keep='last')
    print('Количество удаленных строк, которые были дубликатами: ', current_number_of_raws - data.shape[0])
    
    current_number_of_raws = data.shape[0]
    fraud_ids = set(data[data['Маржа'] <= -300.0]['НомерЗаказаНаСайте'].unique())
    data = data[~data['НомерЗаказаНаСайте'].isin(fraud_ids)]
    print('Количество удаленных строк, которые являются фродом: ', current_number_of_raws - data.shape[0])
    print('Количество удаленных чеков, которые являются фродом: ', len(fraud_ids))
    
    data = data.drop(columns=['СуммаЗаказаНаСайте', 'СуммаДокумента'])
    
    print('Итоговое количество строк: ', data.shape[0])
    return data

# %%
data = prepare_data(order_data)

# document_sums = data.groupby(['НомерЗаказаНаСайте', 'НовыйСтатус'])['СуммаСтроки'].sum().reset_index()
# Out:
# Количество удаленных строк, которые описывают доставку:  325123
# Количество удаленных строк, где пропущены ключевые значения:  4843
# Количество удаленных строк, которые были дубликатами:  2406
# Количество удаленных строк, которые являются фродом:  70384
# Количество удаленных чеков, которые являются фродом:  18395
# Итоговое количество строк:  1270511

# %% [markdown]
# Проверим получилось ли у нас исправить данные:

# %%
### TO DO: проверить данные

# %% [markdown]
# Отлично все получилось!

# %% [markdown]
# ### Выделяем размещенные товары ###

# %% [markdown]
# Чтобы упростить работу с размещенными товарами оставим каждый чек по одному разу. Для этого нам нужно удалить все дубликаты с одинаковыми значениями в колонках 'НомерЗаказаНаСайте', 'Номенклатура' (Заметим, что пропущенных значений в номенклатуре нет) и 'Количество'.

# %%
def get_posted_goods(data):
    current_number_of_raws = data.shape[0]
    data = data.drop_duplicates(subset=['НомерЗаказаНаСайте', 'Номенклатура', 'Количество'], keep='last')
    print('Количество удаленных строк: ', current_number_of_raws - data.shape[0])
    print('Итоговых количество строк: ', data.shape[0])
    return data

# %%
posted_data = get_posted_goods(data)
# Out:
# Количество удаленных строк:  23285
# Итоговых количество строк:  1247226

# %% [markdown]
# ### Выделяем выкупленные товары

# %% [markdown]
# Для начала посмотрим какие значения принимает НовыйСтатус:

# %%
print(data['НовыйСтатус'].unique())
# Out:
# ['Доставлен' 'Возврат из ПВЗ' 'К отгрузке' 'Отменен' 'Расформирован ПВЗ'
#  'Принят в ПВЗ' 'Отменяется' 'Частичный возврат' 'Скомплектован Регион'
#  'В резерве' 'Возврат' 'Отправлен в ПВЗ' 'Комплектация Регион'
#  'Передан в Регион']

# %% [markdown]
# <p>Исходя из этих данных нетрудно понять, что заказ на пути от корзины сайта до получателя проходит достаточно длинный путь. Будем считать, что выкупленные товары это только те у которых 'НовыйСтатус' равно 'Доставлен'.<br><br>Теперь посмотрим какие значения в таком случае принимает колонка 'Отменено'.</p>

# %%
data[data['НовыйСтатус'] == 'Доставлен'].groupby('Отменено').size()
# Out:
# Отменено
# Да       6666
# Нет    352541
# dtype: int64

# %% [markdown]
# <p>Как можно заметить, даже при 'НовыйСтатус' = 'Доставлен' у нас 'Отменено' может принимать значение 'Нет'. Мы считаем, что колонка 'Отменено' первична, следовательно, заказы которые доставлены, но отменены мы учитывать не будем.</p>
# <p>Таким образом мы можем сделать вывод какие товары являются выкупленными:</p>

# %% [markdown]
# Теперь посмотрим на 'Количество' и 'КоличествоПроданоКлиенту', узнаем существуют ли варианты где они не равны

# %%
data[data['Количество'] != data['КоличествоПроданоКлиенту']].head()
# Out:
#                 Дата     ДатаДоставки НомерЗаказаНаСайте     НовыйСтатус  \
# 29   01.07.2017 0:01  04.07.2017 0:00         5031806_TR  Возврат из ПВЗ
# 32   01.07.2017 0:22  04.07.2017 0:00         5031794_TR  Возврат из ПВЗ
# 33   01.07.2017 0:22  04.07.2017 0:00         5031794_TR  Возврат из ПВЗ
# 42   01.07.2017 0:24  19.07.2017 0:00         5031802_TR  Возврат из ПВЗ
# 49  01.07.2017 10:37  06.07.2017 0:00         5031807_TR       Доставлен
#
#    МетодДоставки  ФормаОплаты           Регион                   Группа2  \
# 29      Магазины  Безналичная           Москва  КАНЦТОВАРЫ, КНИГИ, ДИСКИ
# 32      Магазины  Безналичная           Москва                     ОБУВЬ
# 33      Магазины  Безналичная           Москва                     ОБУВЬ
# 42      Магазины  Безналичная        Челябинск  КАНЦТОВАРЫ, КНИГИ, ДИСКИ
# 49      Магазины  Безналичная  Санкт-Петербург        ТЕКСТИЛЬ, ТРИКОТАЖ
#
#                                Группа3                 Группа4      Тип  \
# 29                          КАНЦТОВАРЫ  ранцы, рюкзаки, пеналы  ИГРУШКИ
# 32                       ОБУВЬ ДЕТСКАЯ         резиновая обувь   ОДЕЖДА
# 33                       ОБУВЬ ДЕТСКАЯ         резиновая обувь   ОДЕЖДА
# 42                          КАНЦТОВАРЫ  ранцы, рюкзаки, пеналы  ИГРУШКИ
# 49  ОДЕЖДА ДЛЯ НОВОРОЖДЕННЫХ (0-2 лет)               песочники   ОДЕЖДА
#
#                                          Номенклатура ТипТовара Отменено  \
# 29  ERICH KRAUSE, РАНЕЦ раскладной Sea Woolf ( мод...       МГТ      Нет
# 32  NORDMAN, РЕЗИНА неутепленная, (роз), р. 31/32-...       МГТ      Нет
# 33    ДЮНА, РЕЗИНА неутепленная, (в ассорт), р. 23-26       МГТ      Нет
# 42  ERICH KRAUSE, РАНЕЦ с эргономичной спинкой Dor...       МГТ      Нет
# 49  LEADER KIDS, ПОЛУКОМБИНЕЗОН-песочник Морской к...       МГТ      Нет
#
#    ПричинаОтмены  Количество    Цена  СуммаСтроки  ЦенаЗакупки  \
# 29           NaN           1  3040.0       3040.0      2763.56
# 32           NaN           1   310.0        310.0       238.45
# 33           NaN           1   410.0        410.0       315.00
# 42           NaN           1  1652.0       1652.0      1180.00
# 49           NaN           1   125.3        125.3       120.00
#
#     МесяцДатыЗаказа ГодДатыЗаказа    ПВЗ_код     Статус      Гео   Маржа  \
# 29                7         2 017      23111    Возврат   Москва  276.44
# 32                7         2 017      23111    Возврат   Москва   71.55
# 33                7         2 017      23111    Возврат   Москва   95.00
# 42                7         2 017      23111    Возврат  Регионы  472.00
# 49                7         2 017  901000646  Доставлен  Регионы    5.30
#
#    СуммаУслуг СуммаДоставки  НомерСтроки  КоличествоПроданоКлиенту  \
# 29         49            49            1                         0
# 32         49            49            2                         0
# 33         49            49            1                         0
# 42         99            99            1                         0
# 49         99            99            3                         0
#
#    ДатаЗаказаНаСайте              Телефон_new           ЭлектроннаяПочта_new  \
# 29   30.06.2017 0:00  55575451-55554850515276             97117_au19@mail.ru
# 32   30.06.2017 0:00  55575054-54575350505479  guest_103117_gu28@workmail.ru
# 33   30.06.2017 0:00  55575054-54575350505479  guest_103117_gu28@workmail.ru
# 42   30.06.2017 0:00  55575348-55515057485574          114117_ru21@yandex.ru
# 49   30.06.2017 0:00  55575649-56544856514878            107117_ku17@mail.ru
#
#      Клиент          ID_SKU ГородМагазина МагазинЗаказа
# 29  Наумова  IDL00046097048             0           NaN
# 32    Гость  IDL00046162957             0           NaN
# 33    Гость  IDL00048176149             0           NaN
# 42    Гость  IDL00046097149             0           NaN
# 49     Анна  IDL00034067149             0           NaN

# %% [markdown]
# Заметим, что если 'Количество' не равно 'КоличествоПроданоКлиенту', то 'СуммаСтроки' и 'Маржа' пересчитываются по 'Количество' следовательно, чтобы исправить корректность данных, анализируя выкупленные товары, нам необходимо пересчитать их по 'КоличествоПроданоКлиенту'. Давайте сразу удалим те строки в которых 'КоличествоПроданоКлиенту' равно 0.

# %% [markdown]
# Таким образом чтобы выделить выкупленные товары нам нужно:
# * Оставить только те строки, где 'НовыйСтатус' == 'Доставлен', а 'Отменено' == 'Нет'
# * Удалить все строчки, где пропущено значение в столбце 'КоличествоПроданоКлиенту'
# * Удалить все строчки, где 'КоличествоПроданоКлиенту' <= 0
# * Пересчитать основные показатели через КоличествоПроданоКлиенту, а не через Количество

# %%
def get_purchased_goods(data):
    current_number_of_raws = data.shape[0]
    data = data[data['НовыйСтатус'] == 'Доставлен'][data['Отменено'] == 'Нет']
    print('Количество удаленных строк, где товар не доставлен или отменен: ', current_number_of_raws - data.shape[0])
    
    current_number_of_raws = data.shape[0]
    data = data.dropna(subset=['КоличествоПроданоКлиенту'])
    print('Количество удаленных строк, где пропущено значение в колонке \'КоличествоПроданоКлиенту\':', current_number_of_raws - data.shape[0])
    
    current_number_of_raws = data.shape[0]
    data = data[data['КоличествоПроданоКлиенту'] > 0]
    print('Количество удаленных строк, где \'КоличествоПроданоКлиенту\' <= 0: ', current_number_of_raws - data.shape[0])
    
    data['СуммаСтроки'] = data['Цена'] * data['КоличествоПроданоКлиенту']
    data['Маржа'] = (data['Цена'] - data['ЦенаЗакупки']) * data['КоличествоПроданоКлиенту']
    
    print('Итоговое количество строк: ', data.shape[0])
    return data

purchased_data = get_purchased_goods(data)
# Out:
# /Users/millb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Количество удаленных строк, где товар не доставлен или отменен:  744292
# Количество удаленных строк, где пропущено значение в колонке 'КоличествоПроданоКлиенту': 0
# Количество удаленных строк, где 'КоличествоПроданоКлиенту' <= 0:  5147
# Итоговое количество строк:  521072

# %% [markdown]
# Проверим получившиеся данные:

# %%
### TO DO: проверить данные

# %% [markdown]
# Отлично все получилось!

# %% [markdown]
# ## Построение аналитической отчестности ##

# %% [markdown]
# Для начала, на всякий случай еще раз подготовим все данные:

# %%
data = prepare_data(order_data)
# Out:
# Количество удаленных строк, которые описывают доставку:  325123
# Количество удаленных строк, где пропущены ключевые значения:  4843
# Количество удаленных строк, которые были дубликатами:  2406
# Количество удаленных строк, которые являются фродом:  70384
# Количество удаленных чеков, которые являются фродом:  18395
# Итоговое количество строк:  1270511

# %%
posted_data = get_posted_goods(data)
# Out:
# Количество удаленных строк:  23285
# Итоговых количество строк:  1247226

# %%
purchased_data = get_purchased_goods(data)
# Out:
# /Users/millb/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Количество удаленных строк, где товар не доставлен или отменен:  744292
# Количество удаленных строк, где пропущено значение в колонке 'КоличествоПроданоКлиенту': 0
# Количество удаленных строк, где 'КоличествоПроданоКлиенту' <= 0:  5147
# Итоговое количество строк:  521072

# %% [markdown]
# ### Основные показатели по месяцам ###
# * Выручка
# * Кол-во уникальных чеков
# * Средний чек
# * средняя цена
# * Средняя маржа
# * средний % маржи
# * Кол-во товаров
# * Кол-во уникальных клиентов
# * Среднее количество товаров в чеке

# %%
def get_basic_indicators(data):
    data = data.groupby(['МесяцДатыЗаказа'])['СуммаСтроки'].sum().reset_index()
    data

# %% [markdown]
# #### Размещенные товары ####

# %%
### code

# %% [markdown]
# #### Выкупленные товары ####

# %%
data = data.groupby

# %% [markdown]
# ### Выкупаемость ###
